# %%
import cv2
import numpy as np
from modules import cvTools as ct
from importlib import reload
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # 1. Sample code

# %%
from modules import cvTools as ct
from modules import create_xml 
reload(ct)
labeling_main_folder = '/Users/chiang-en/Documents/GitHub/cvTools/'
labeling_sub_folder = 'test/'
bg_folder = '/Users/chiang-en/Documents/GitHub/cvTools/imgs/'
bg_name = 'test.png'
obj_label = 'face'
obj_folder = '/Users/chiang-en/Documents/faces/faces_jpg/'
num_objs = 100
save_title = 'test'
sample_xml_path = 'sample.xml'
create_xml.patching_xml(labeling_main_folder,labeling_sub_folder,bg_folder,bg_name,obj_label,obj_folder,num_objs,save_title, sample_xml_path)
# Out:
# <object><name /></object>
# <object><name /><pose /></object>
# <object><name /><pose /><truncated /></object>
# <object><name /><pose /><truncated /><difficult /></object>
# <object><name /><pose /><truncated /><difficult /><bndbox /></object>
# <bndbox><xmin /></bndbox>
# <bndbox><xmin>1247</xmin><ymin /></bndbox>
# <bndbox><xmin>1247</xmin><ymin>93</ymin><xmax /></bndbox>
# <bndbox><xmin>1247</xmin><ymin>93</ymin><xmax>1270</xmax><ymax /></bndbox>
# <object><name /></object>
# <object><name /><pose /></object>
# <object><name /><pose /><truncated /></object>
# <object><name /><pose /><truncated /><difficult /></object>
# <object><name /><pose /><truncated /><difficult /><bndbox /></object>
# <bndbox><xmin /></bndbox>
# <bndbox><xmin>1430</xmin><ymin /></bndbox>
# <bndbox><xmin>1430</xmin><ymin>61</ymin><xmax /></bndbox>
# <bndbox><xmin>1430</xmin><ymin>61</ymin><xmax>1453</xmax><ymax /></bndbox>
# <object><name /></object>
# <object><name /><pose /></object>
# ...

# %%
    import xml.etree.ElementTree as ET
    tree = ET.parse(sample_xml_path)
    root = tree.getroot()
    root.find('folder').text
    root.find('size').find('depth').text
# Out:
# '1'

# %%
# https://roboflow.com/formats/labelme-json

# %%
a = (1,2)
a[0]
